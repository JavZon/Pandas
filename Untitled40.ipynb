# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Pandas/blob/main/Untitled40.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/sample_data/california_housing_train.csv')
df.head(10)
df2= df.iloc[0:10, [3,4,5]]
df2.to_excel('new_housing_uzb.xlsx', index=False)

# %%
df.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0

# %%
df.to_csv('nnn.csv', columns=['latitude','households'])

# %%
df2
# Out:
#    total_rooms  total_bedrooms  population
# 0       5612.0          1283.0      1015.0
# 1       7650.0          1901.0      1129.0
# 2        720.0           174.0       333.0
# 3       1501.0           337.0       515.0
# 4       1454.0           326.0       624.0
# 5       1387.0           236.0       671.0
# 6       2907.0           680.0      1841.0
# 7        812.0           168.0       375.0
# 8       4789.0          1175.0      3134.0
# 9       1497.0           309.0       787.0

# %%
dict1= {
    'ABC':[12,23,34],
    'DEF':[45,56,67]
}
df3=pd.DataFrame(dict1)
df3
# Out:
#    ABC  DEF
# 0   12   45
# 1   23   56
# 2   34   67

# %%
with pd.ExcelWriter('yangi_fayl2.xlsx') as file:
  df2.to_excel(file, sheet_name='NNN')
  df3.to_excel(file, sheet_name='NNN')

# %%
with pd.ExcelWriter('yangi_fayl2.xlsx') as file:
    df2.to_excel(file, sheet_name='NNN', startrow=0, startcol=0)
    df3.to_excel(file, sheet_name='NNN', startrow=df2.shape[0]+1, startcol=0)

# %%
import json

# %%
a=[32,'m','rt', 55]
json_var=json.dumps(a)

# %%
type(json_var)
# Out:
# str

# %%
with open('new_data_bbb','w') as f:
  json.dump(a, f)

# %%
my_python=json.loads(json_var)

# %%
my_python
# Out:
# [32, 'm', 'rt', 55]

# %%
my_api_key= '8f3396d78fab485188b6799fbf794fb2'

# %%
import requests

# %%
link='https://newsapi.org/v2/top-headlines?sources=bbc-news&apiKey=8f3396d78fab485188b6799fbf794fb2'
data1=requests.get(link)
data1.status_code
data1.json()
# Out:
# {'status': 'ok',
#  'totalResults': 10,
#  'articles': [{'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'BBC News',
#    'title': 'Lord Jacob Rothschild: Financier dies aged 87',
#    'description': 'In a statement on Monday, his family called Lord Rothschild "a towering presence in many peoples\' lives".',
#    'url': 'https://www.bbc.co.uk/news/business-68404567',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/87E9/production/_132739743_8845448b19bea0f31e8b0785806072ac0664d8e1.jpg',
#    'publishedAt': '2024-02-27T11:22:13.3288056Z',
#    'content': 'Lord Jacob Rothschild, the financier and member of the Rothschild banking family, has died at the age of 87.\r\nIn a statement on Monday, his family called Lord Rothschild "a towering presence in many … [+2724 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'BBC News',
#    'title': 'Gills Aloud? Tiny fish found making very big noise',
# ...

# %%
df=pd.DataFrame(data1.json()['articles'][7])
df
# Out:
#         source    author                                              title  \
# id    bbc-news  BBC News  Charity Atlantic rower Michael Holt found dead...
# name  BBC News  BBC News  Charity Atlantic rower Michael Holt found dead...
#
#                                             description  \
# id    Michael Holt's body was found by the crew of a...
# name  Michael Holt's body was found by the crew of a...
#
#                                                url  \
# id    https://www.bbc.co.uk/news/uk-wales-68403491
# name  https://www.bbc.co.uk/news/uk-wales-68403491
#
#                                              urlToImage  \
# id    https://ichef.bbci.co.uk/news/1024/branded_new...
# name  https://ichef.bbci.co.uk/news/1024/branded_new...
#
#                        publishedAt  \
# id    2024-02-26T22:22:20.0696563Z
# name  2024-02-26T22:22:20.0696563Z
#
#                                                 content
# id    A 54-year-old man from north Wales has been fo...
# ...

# %%
df.at['name', 'content']
# Out:
# 'A 54-year-old man from north Wales has been found dead on his boat during an attempt to row across the Atlantic Ocean. \r\nMichael Holt from Porthmadog, Gwynedd, left Gran Canaria on 27 January with th… [+3149 chars]'
