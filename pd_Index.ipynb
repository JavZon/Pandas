# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Pandas/blob/main/pd_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd
import random

# Sample data for 10 Asian countries
countries = ["China", "India", "Indonesia", "Pakistan", "Bangladesh", "Japan", "Philippines", "Vietnam", "Turkey", "Iran"]
capitals = ["Beijing", "New Delhi", "Jakarta", "Islamabad", "Dhaka", "Tokyo", "Manila", "Hanoi", "Ankara", "Tehran"]
land_area = [9596961, 3287263, 1904569, 881913, 147570, 377975, 300000, 331212, 783562, 1648195]
population = [1439323776, 1380004385, 273523615, 225199937, 164689383, 126476461, 111046913, 97109146, 83154997, 83992953]
unemployment_rate = [5.1, 6.1, 5.3, 4.3, 4.0, 2.8, 5.3, 2.2, 11.0, 10.8]

# Create a DataFrame
data = {
    'Countries': countries,
    'Capital': capitals,
    'Land': land_area,
    'Population': population,
    'Un_rate': unemployment_rate
}

# Create the DataFrame with custom index
index_labels = [f'N{i}' for i in range(1, 11)]
df = pd.DataFrame(data, index=index_labels)

# Display the DataFrame

# %%
df
# Out:
#        Countries    Capital     Land  Population  Un_rate
# N1         China    Beijing  9596961  1439323776      5.1
# N2         India  New Delhi  3287263  1380004385      6.1
# N3     Indonesia    Jakarta  1904569   273523615      5.3
# N4      Pakistan  Islamabad   881913   225199937      4.3
# N5    Bangladesh      Dhaka   147570   164689383      4.0
# N6         Japan      Tokyo   377975   126476461      2.8
# N7   Philippines     Manila   300000   111046913      5.3
# N8       Vietnam      Hanoi   331212    97109146      2.2
# N9        Turkey     Ankara   783562    83154997     11.0
# N10         Iran     Tehran  1648195    83992953     10.8

# %%
df['Countries']
# Out:
# N1           China
# N2           India
# N3       Indonesia
# N4        Pakistan
# N5      Bangladesh
# N6           Japan
# N7     Philippines
# N8         Vietnam
# N9          Turkey
# N10           Iran
# Name: Countries, dtype: object

# %%
df['LS']=['Rich' if rate > 5.6899 else 'Poor' for rate in df['Un_rate']]
df
# Out:
#        Countries    Capital     Land  Population  Un_rate    LS
# N1         China    Beijing  9596961  1439323776      5.1  Poor
# N2         India  New Delhi  3287263  1380004385      6.1  Rich
# N3     Indonesia    Jakarta  1904569   273523615      5.3  Poor
# N4      Pakistan  Islamabad   881913   225199937      4.3  Poor
# N5    Bangladesh      Dhaka   147570   164689383      4.0  Poor
# N6         Japan      Tokyo   377975   126476461      2.8  Poor
# N7   Philippines     Manila   300000   111046913      5.3  Poor
# N8       Vietnam      Hanoi   331212    97109146      2.2  Poor
# N9        Turkey     Ankara   783562    83154997     11.0  Rich
# N10         Iran     Tehran  1648195    83992953     10.8  Rich

# %%
ind1
# Out:
# Index(['Countries', 'Capital', 'Land', 'Population', 'Un_rate'], dtype='object')

# %%
ind1[-1]
# Out:
# 'Un_rate'

# %%
del df['Land']
df
# Out:
#        Countries    Capital  Population  Un_rate    LS
# N1         China    Beijing  1439323776      5.1  Poor
# N2         India  New Delhi  1380004385      6.1  Rich
# N3     Indonesia    Jakarta   273523615      5.3  Poor
# N4      Pakistan  Islamabad   225199937      4.3  Poor
# N5    Bangladesh      Dhaka   164689383      4.0  Poor
# N6         Japan      Tokyo   126476461      2.8  Poor
# N7   Philippines     Manila   111046913      5.3  Poor
# N8       Vietnam      Hanoi    97109146      2.2  Poor
# N9        Turkey     Ankara    83154997     11.0  Rich
# N10         Iran     Tehran    83992953     10.8  Rich

# %%
dict2={
    'Age':[25,41,23,31],
    'Job':['Doctor','Teacher','Singer','Boxer'],
    'Salary':[65000,28000,35000,73000]
}

# %%
gps=pd.DataFrame(dict2, index=['Ali','Vali','Nodir','Ali'])
gps
# Out:
#        Age      Job  Salary
# Ali     25   Doctor   65000
# Vali    41  Teacher   28000
# Nodir   23   Singer   35000
# Ali     31    Boxer   73000

# %%
gps.index
# Out:
# Index(['Ali', 'Vali', 'Nodir', 'Ali'], dtype='object')

# %%
gps.loc['Ali']
# Out:
#      Age     Job  Salary
# Ali   25  Doctor   65000
# Ali   31   Boxer   73000

# %%
ind1=pd.Index(['Nodir','Bolta','Tohir'])
ind1.isin(gps.index)
# Out:
# array([ True, False, False])

# %%
index1=pd.Index([1,2,3,4,5])
index2=pd.Index([1,8,21,3,5])
new_index=index1.union(index2)
new_index
# Out:
# Int64Index([1, 2, 3, 4, 5, 8, 21], dtype='int64')

# %%
ind=pd.Index([23,45,80,13,6])
new_ind=ind.insert(3, "Olim")
new_ind
# Out:
# Index([23, 45, 80, 'Olim', 13, 6], dtype='object')

# %%
ind.is_monotonic
# Out:
# <ipython-input-16-f5a441aa15c7>:1: FutureWarning: is_monotonic is deprecated and will be removed in a future version. Use is_monotonic_increasing instead.
#   ind.is_monotonic
# False
