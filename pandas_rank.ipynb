# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Pandas/blob/main/pandas_rank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data={
    'a':[2,8,0],
    'b':[3,91,18],
    'c':[41,89,31],
    'd':[26,5,23]
}

ind=['r1','r2','r3']
df=pd.DataFrame(data, index=ind)
df
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df.sort_values(by=['d','c'])
# Out:
#     a   b   c   d
# r2  8  91  89   5
# r3  0  18  31  23
# r1  2   3  41  26

# %%
df['a']
# Out:
# r1    2
# r2    8
# r3    0
# Name: a, dtype: int64

# %%
df['w']=['Rich' if x>4 else 0 for x in df['a']]
df #['Rich' if x > 4 else 'Poor' for x in df['a']]
# Out:
#     a   b   c   d     w
# r1  2   3  41  26     0
# r2  8  91  89   5  Rich
# r3  0  18  31  23     0

# %%
df.rank(axis='columns')
# Out:
# <ipython-input-9-473402465564>:1: FutureWarning: Dropping of nuisance columns in DataFrame.rank is deprecated; in a future version this will raise TypeError. Select only valid columns before calling rank.
#   df.rank(axis='columns')
#       a    b    c    d
# r1  1.0  2.0  4.0  3.0
# r2  2.0  4.0  3.0  1.0
# r3  1.0  2.0  4.0  3.0

# %%
'ba' in df.columns
# Out:
# False

# %%
in1=df.columns
ind2=df.index
print(in1)
print(ind2)
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')
# Index(['r1', 'r2', 'r3'], dtype='object')

# %%
in1.isin(ind2)
# Out:
# array([False, False, False, False])

# %%
in1.union(ind2)
# Out:
# Index(['a', 'b', 'c', 'd', 'r1', 'r2', 'r3'], dtype='object')

# %%
in1.insert(2, 'o')
# Out:
# Index(['a', 'b', 'o', 'c', 'd'], dtype='object')

# %%
in1.get_loc('c')
# Out:
# 2

# %%
in1.to_numpy()
# Out:
# array(['a', 'b', 'c', 'd'], dtype=object)

# %%
df
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df.reindex(['r1','r3','W'], fill_value=0)
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r3  0  18  31  23
# W   0   0   0   0

# %%
df
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df.reindex(columns=['d','b','w'], fill_value='OBSO')
# Out:
#      d   b     w
# r1  26   3  OBSO
# r2   5  91  OBSO
# r3  23  18  OBSO

# %%
df.reindex(index=['r2','r1'], columns=['c','d'])
# Out:
#      c   d
# r2  89   5
# r1  41  26

# %%
df
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df.loc[['r1','r3'],['b','d']]
# Out:
#      b   d
# r1   3  26
# r3  18  23

# %%
df2=df.reindex(['r1','r3','x'])
df2.fillna(method='bfill')
# Out:
#       a     b     c     d
# r1  2.0   3.0  41.0  26.0
# r3  0.0  18.0  31.0  23.0
# x   NaN   NaN   NaN   NaN

# %%
df2.drop(columns='d', index='x')
# Out:
#       a     b     c
# r1  2.0   3.0  41.0
# r3  0.0  18.0  31.0

# %%
df
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df[['a','d']]
# Out:
#     a   d
# r1  2  26
# r2  8   5
# r3  0  23

# %%
df
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df[(df['d']>20) & (df['a']>1)]
# Out:
#     a  b   c   d
# r1  2  3  41  26

# %%
df[df['d'].isin([26,3])]
# Out:
#     a  b   c   d
# r1  2  3  41  26

# %%
df.loc[df['c']>35, ['a','d']]
# Out:
#     a   d
# r1  2  26
# r2  8   5

# %%
df
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df.iloc[:2, ::3]
# Out:
#     a   d
# r1  2  26
# r2  8   5

# %%
df.query("d>20")
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r3  0  18  31  23

# %%
df
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df.sum(axis=1)
# Out:
# r1     72
# r2    193
# r3     72
# dtype: int64

# %%
df
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df.iat[1,2]
# Out:
# 89

# %%
df.idxmin()
# Out:
# a    r3
# b    r1
# c    r3
# d    r2
# dtype: object

# %%
df2
# Out:
#       a     b     c     d
# r1  2.0   3.0  41.0  26.0
# r3  0.0  18.0  31.0  23.0
# x   NaN   NaN   NaN   NaN

# %%
df
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df.mean(axis=1)
# Out:
# r1    18.00
# r2    48.25
# r3    18.00
# dtype: float64

# %%
df.apply(sum)
# Out:
# a     10
# b    112
# c    161
# d     54
# dtype: int64

# %%
df
# Out:
#     a   b   c   d         W
# r1  2   3  41  26  Zakonniy
# r2  8  91  89   5     Tufta
# r3  0  18  31  23  Zakonniy

# %%
df.apply(lambda x : x.max()-x.mean())
# Out:
# a     4.666667
# b    53.666667
# c    35.333333
# d     8.000000
# dtype: float64

# %%
df
# Out:
#     a   b   c   d         W
# r1  2   3  41  26  Zakonniy
# r2  8  91  89   5     Tufta
# r3  0  18  31  23  Zakonniy

# %%
def cond(x):
  return 'High' if x>6 else 'Low'

df['W']=df['d'].apply(lambda x : 'Zakonniy' if x>6 else 'Tufta')

# %%
df.sum(axis=1)
# Out:
# <ipython-input-93-f6cc363c055e>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum(axis=1)
# r1     72
# r2    193
# r3     72
# dtype: int64

# %%
df3=df.drop(columns='W')

# %%
df
# Out:
#     a   b   c   d         W
# r1  2   3  41  26  Zakonniy
# r2  8  91  89   5     Tufta
# r3  0  18  31  23  Zakonniy

# %%
df3
# Out:
#     a   b   c   d
# r1  2   3  41  26
# r2  8  91  89   5
# r3  0  18  31  23

# %%
df3['z']=df3.apply(lambda x : x['a']+x['c'], axis=1)

# %%
df3
# Out:
#     a   b   c   d   z
# r1  2   3  41  26  43
# r2  8  91  89   5  97
# r3  0  18  31  23  31

# %%
df3['d'].sort_values(ascending=False)
# Out:
# r1    26
# r3    23
# r2     5
# Name: d, dtype: int64

# %%
df3.sort_values(by='z', ascending=False)
# Out:
#     a   b   c   d   z
# r2  8  91  89   5  97
# r1  2   3  41  26  43
# r3  0  18  31  23  31

# %%
data={
    'Club':['RMA', 'FCB','ATM','RMA','ATM','FCB' ],
    'Players':['Kross','Yamal','Griezman','Vinicius','Morata','Gavi'],
    'Salary':[18.5, 3.4, 20.7, 12.4, 7.9, 9.2]
}

ind=['r1','r2','r3','r4','r5','r6']
df4=pd.DataFrame(data, index=ind)
df4
# Out:
#    Club   Players  Salary
# r1  RMA     Kross    18.5
# r2  FCB     Yamal     3.4
# r3  ATM  Griezman    20.7
# r4  RMA  Vinicius    12.4
# r5  ATM    Morata     7.9
# r6  FCB      Gavi     9.2

# %%
df4.rank(axis=1)
# Out:
# <ipython-input-115-e247b881051d>:1: FutureWarning: Dropping of nuisance columns in DataFrame.rank is deprecated; in a future version this will raise TypeError. Select only valid columns before calling rank.
#   df4.rank(axis=1)
#     Salary
# r1     1.0
# r2     1.0
# r3     1.0
# r4     1.0

# %%
df
# Out:
#     a   b   c   d         W
# r1  2   3  41  26  Zakonniy
# r2  8  91  89   5     Tufta
# r3  0  18  31  23  Zakonniy

# %%
df[['c']].rank()
# Out:
#       c
# r1  2.0
# r2  3.0
# r3  1.0

# %%
df4
# Out:
#    Club   Players  Salary
# r1  RMA     Kross    18.5
# r2  FCB     Yamal     3.4
# r3  ATM  Griezman    20.7
# r4  RMA  Vinicius    12.4
# r5  ATM    Morata     7.9
# r6  FCB      Gavi     9.2

# %%
df4.groupby('Club')[['Salary']].rank()
# Out:
#     Salary
# r1     2.0
# r2     1.0
# r3     2.0
# r4     1.0
# r5     1.0
# r6     2.0
